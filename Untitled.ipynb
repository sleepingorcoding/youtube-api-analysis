# %%
from googleapiclient.discovery import build 
import pandas as pd
from dateutil import parser
from IPython.display import JSON 

#Data Packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
api_key = ''

# %%
channel_ids = ["UC_j-aKQp6WIDMdLkN8P3WYw",
               #add more channels here
              ]

# %%
api_service_name = "youtube"
api_version = "v3"
    
# Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=api_key)

request = youtube.channels().list(
    part="snippet,contentDetails,statistics",
    id=','.join(channel_ids)
)
response = request.execute()

JSON(response)

# %%
def get_channel_stats(youtube, channel_ids):
    
    all_data = []
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    # loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        
        all_data.append(data)
        
    return(pd.DataFrame(all_data))

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#   channelName subscribers      views totalVideos                playlistId
# 0         STK      157000  113969724         438  UU_j-aKQp6WIDMdLkN8P3WYw

# %%
playlist_id = "UU_j-aKQp6WIDMdLkN8P3WYw"

def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
len(video_ids)
# Out:
# 438

# %%
def get_video_details(youtube, video_ids):

    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    
    return pd.DataFrame(all_video_info)

# %%
# Get video details
video_df = get_video_details(youtube, video_ids)
video_df
# Out:
#         video_id channelTitle  \
# 0    2N-IPKcWisM          STK
# 1    ssRnz1r7Ijg          STK
# 2    jVjvq0DeVqI          STK
# 3    eMgWNDdqcXc          STK
# 4    oRCnnHx5kuc          STK
# ..           ...          ...
# 433  eViEINUyxPE          STK
# 434  jO7qELH8H24          STK
# 435  _1H63QvnZmA          STK
# 436  H5foQ15KBEk          STK
# 437  Zy0w2d2Qvv8          STK
#
#                                                  title  \
# 0    JDCR vs. Knee | FT2 Exhibition | EVO 2022 Anno...
# 1    Binchang vs. Joey Fury | Grand Finals | TEKKEN...
# 2    Arslan Ash vs. Anakin | Amazing Grand Finals S...
# 3    EVO Rematch | JDCR vs. Saint | Grand Finals | ...
# 4    Chanel vs. Saint | Korea Master's Event | TEKK...
# ..                                                 ...
# 433            [TTT2] Online Battles #2 vs. alt8675309
# 434             [TTT2] Online Lobby #1 w/ dragondude98
# 435  [TTT2] BladeCutter (JACK/NINA) vs. TKS (FENG/GAN)
# 436                                 [TR] 1-Bar Warrior
# 437                                 [TTT2] TheKingHold
#
#                                            description  \
# 0    This footage belongs to:\ntwitch.tv/evo\n\nJDC...
# 1    Binchang vs. Joey Fury\n\nTEKKEN Online Challe...
# 2    Arslan Ash (Zafina) vs. Anakin (Jack)\n\nTEKKE...
# 3    JDCR (Armor King) vs. Saint (Ganryu)\n\n\nJDCR...
# 4    Chanel (Eliza/Zafina) vs. Saint (Ganryu)\n\nTE...
# ..                                                 ...
# 433  alt675309 (BRYAN/DRAGUNOV) vs. ShadowZero-X- (...
# 434  Just a few games with dragondude98\r\n\r\nStil...
# 435                            Tekken Tag Tournament 2
# 436  Tekken Revolution\n\nPlayers featured in this ...
# 437  Had the privilege of fighting the best King pl...
#
#                                                   tags           publishedAt  \
# 0    [鉄拳, 鉄拳7, news, new, high level, pro, best pla...  2022-03-11T17:00:03Z
# 1    [鉄拳, 鉄拳7, lei, julia, news, new, high level, p...  2022-01-10T17:00:41Z
# 2    [鉄拳, 鉄拳7, news, new, high level, pro, best pla...  2021-12-06T17:00:28Z
# 3    [鉄拳, 鉄拳7, lei, julia, news, new, high level, p...  2021-10-10T17:00:17Z
# 4    [鉄拳, 鉄拳7, lei, julia, news, new, high level, p...  2021-10-10T16:45:01Z
# ..                                                 ...                   ...
# 433                [Tekken, 'Tekken Tag Tournament 2']  2015-05-04T01:12:59Z
# 434               [Tekken, ' Tekken Tag Tournament 2']  2015-05-03T08:07:05Z
# 435                                           [Tekken]  2015-05-02T19:47:00Z
# 436                                               None  2015-05-02T16:16:05Z
# 437  [Tekken, 'Tekken Tag Tournament 2', ' Tekken o...  2015-05-01T08:16:52Z
#
#     viewCount likeCount favouriteCount commentCount  duration definition  \
# 0       70351      1157           None          152   PT9M25S         hd
# 1       64644      1043           None          103  PT38M52S         hd
# 2      481709      5830           None          802  PT27M30S         hd
# 3      266555      2663           None           86  PT36M51S         hd
# 4       12446       245           None            6  PT13M50S         hd
# ..        ...       ...            ...          ...       ...        ...
# 433       256         5           None            0   PT3M41S         hd
# 434       139         3           None            0   PT15M1S         sd
# 435       590         9           None            1    PT3M9S         sd
# 436       179         3           None            0   PT2M13S         sd
# 437      1181        26           None            7   PT4M19S         hd
#
#     caption
# 0     false
# 1     false
# 2     false
# 3     false
# 4     false
# ..      ...
# 433   false
# 434   false
# 435   false
# 436   false
# 437   false
#
# [438 rows x 13 columns]

# %% [markdown]
# ## Data pre-processing

# %%
# Looking for NULL values
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount          True
# favouriteCount     True
# commentCount      False
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
# Checking data types
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis=1)

# %%
# Publish day in the week
video_df['publishedAt'] = video_df['publishedAt'].apply(lambda x: parser.parse(x)) 
video_df['pushblishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
import isodate
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df[['durationSecs', 'duration']]
# Out:
#      durationSecs  duration
# 0           565.0   PT9M25S
# 1          2332.0  PT38M52S
# 2          1650.0  PT27M30S
# 3          2211.0  PT36M51S
# 4           830.0  PT13M50S
# ..            ...       ...
# 433         221.0   PT3M41S
# 434         901.0   PT15M1S
# 435         189.0    PT3M9S
# 436         133.0   PT2M13S
# 437         259.0   PT4M19S
#
# [438 rows x 2 columns]

# %%
# Add tag count
video_df['tagCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
video_df
# Out:
#         video_id channelTitle  \
# 0    2N-IPKcWisM          STK
# 1    ssRnz1r7Ijg          STK
# 2    jVjvq0DeVqI          STK
# 3    eMgWNDdqcXc          STK
# 4    oRCnnHx5kuc          STK
# ..           ...          ...
# 433  eViEINUyxPE          STK
# 434  jO7qELH8H24          STK
# 435  _1H63QvnZmA          STK
# 436  H5foQ15KBEk          STK
# 437  Zy0w2d2Qvv8          STK
#
#                                                  title  \
# 0    JDCR vs. Knee | FT2 Exhibition | EVO 2022 Anno...
# 1    Binchang vs. Joey Fury | Grand Finals | TEKKEN...
# 2    Arslan Ash vs. Anakin | Amazing Grand Finals S...
# 3    EVO Rematch | JDCR vs. Saint | Grand Finals | ...
# 4    Chanel vs. Saint | Korea Master's Event | TEKK...
# ..                                                 ...
# 433            [TTT2] Online Battles #2 vs. alt8675309
# 434             [TTT2] Online Lobby #1 w/ dragondude98
# 435  [TTT2] BladeCutter (JACK/NINA) vs. TKS (FENG/GAN)
# 436                                 [TR] 1-Bar Warrior
# 437                                 [TTT2] TheKingHold
#
#                                            description  \
# 0    This footage belongs to:\ntwitch.tv/evo\n\nJDC...
# 1    Binchang vs. Joey Fury\n\nTEKKEN Online Challe...
# 2    Arslan Ash (Zafina) vs. Anakin (Jack)\n\nTEKKE...
# 3    JDCR (Armor King) vs. Saint (Ganryu)\n\n\nJDCR...
# 4    Chanel (Eliza/Zafina) vs. Saint (Ganryu)\n\nTE...
# ..                                                 ...
# 433  alt675309 (BRYAN/DRAGUNOV) vs. ShadowZero-X- (...
# 434  Just a few games with dragondude98\r\n\r\nStil...
# 435                            Tekken Tag Tournament 2
# 436  Tekken Revolution\n\nPlayers featured in this ...
# 437  Had the privilege of fighting the best King pl...
#
#                                                   tags  \
# 0    [鉄拳, 鉄拳7, news, new, high level, pro, best pla...
# 1    [鉄拳, 鉄拳7, lei, julia, news, new, high level, p...
# 2    [鉄拳, 鉄拳7, news, new, high level, pro, best pla...
# 3    [鉄拳, 鉄拳7, lei, julia, news, new, high level, p...
# 4    [鉄拳, 鉄拳7, lei, julia, news, new, high level, p...
# ..                                                 ...
# 433                [Tekken, 'Tekken Tag Tournament 2']
# 434               [Tekken, ' Tekken Tag Tournament 2']
# 435                                           [Tekken]
# 436                                               None
# 437  [Tekken, 'Tekken Tag Tournament 2', ' Tekken o...
#
#                   publishedAt  viewCount  likeCount  favouriteCount  \
# 0   2022-03-11 17:00:03+00:00    70351.0     1157.0             NaN
# 1   2022-01-10 17:00:41+00:00    64644.0     1043.0             NaN
# 2   2021-12-06 17:00:28+00:00   481709.0     5830.0             NaN
# 3   2021-10-10 17:00:17+00:00   266555.0     2663.0             NaN
# 4   2021-10-10 16:45:01+00:00    12446.0      245.0             NaN
# ..                        ...        ...        ...             ...
# 433 2015-05-04 01:12:59+00:00      256.0        5.0             NaN
# 434 2015-05-03 08:07:05+00:00      139.0        3.0             NaN
# 435 2015-05-02 19:47:00+00:00      590.0        9.0             NaN
# 436 2015-05-02 16:16:05+00:00      179.0        3.0             NaN
# 437 2015-05-01 08:16:52+00:00     1181.0       26.0             NaN
#
#      commentCount  duration definition caption pushblishDayName  durationSecs  \
# 0           152.0   PT9M25S         hd   false           Friday         565.0
# 1           103.0  PT38M52S         hd   false           Monday        2332.0
# 2           802.0  PT27M30S         hd   false           Monday        1650.0
# 3            86.0  PT36M51S         hd   false           Sunday        2211.0
# 4             6.0  PT13M50S         hd   false           Sunday         830.0
# ..            ...       ...        ...     ...              ...           ...
# 433           0.0   PT3M41S         hd   false           Monday         221.0
# 434           0.0   PT15M1S         sd   false           Sunday         901.0
# 435           1.0    PT3M9S         sd   false         Saturday         189.0
# 436           0.0   PT2M13S         sd   false         Saturday         133.0
# 437           7.0   PT4M19S         hd   false           Friday         259.0
#
#      tagCount
# 0          16
# 1          19
# 2          21
# 3          20
# 4          21
# ..        ...
# 433         2
# 434         2
# 435         1
# 436         0
# 437         3
#
# [438 rows x 16 columns]

# %% [markdown]
# ### Best Performing Videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=False)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# ### Views vs Likes & Comments

# %%
fig, ax = plt.subplots(1,2)
sns.scatterplot(data = video_df, x = 'commentCount', y = 'viewCount', ax = ax[0])
sns.scatterplot(data = video_df, x = 'likeCount', y = 'viewCount', ax = ax[1])
# Out:
# <AxesSubplot:xlabel='likeCount', ylabel='viewCount'>

# %% [markdown]
# ### Duration of videos

# %%
sns.histplot(data = video_df, x = 'durationSecs', bins=30)
# Out:
# <AxesSubplot:xlabel='durationSecs', ylabel='Count'>

# %% [markdown]
# ### Uploading Schedule

# %%
day_df = pd.DataFrame(video_df['pushblishDayName'].value_counts())
weekdays = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays)
ax = day_df.reset_index().plot.bar(x='index', y='pushblishDayName', rot=0)
